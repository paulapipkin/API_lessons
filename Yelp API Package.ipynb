# %%
import json
with open('/Users/paula/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# import the YelpAPI Class
from yelpapi import YelpAPI
# Create an instance with your key
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
# use our yelp_api variable's search_query method to perform our API call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='Pizza')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 11900

# %%
import pandas as pd
biz = pd.DataFrame(search_results['businesses'])
biz.head(2)
# Out:
#                        id                           alias  \
# 0  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 1  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
#
#                   name                                          image_url  \
# 0  Prince Street Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/HVjttL...
# 1            Juliana's  https://s3-media1.fl.yelpcdn.com/bphoto/OCDZ4n...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/prince-street-pizza-n...          4499
# 1      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2521
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.72308755605564, 'longitude': -...  [pickup, delivery]
# 1  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
#
#   price                                           location         phone  \
# 0     $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 1    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
#
#     display_phone     distance
# 0  (212) 966-4100  1961.877142
# 1  (718) 596-6700   308.569844

# %%
# add offset to our original api call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='Pizza',
                                       offset = 20)

# %%
biz20 = pd.DataFrame(search_results['businesses'])
biz20.head(2)
# Out:
#                        id                        alias                name  \
# 0  xxgcU_oFIox_pAmroo9WwA  front-street-pizza-brooklyn  Front Street Pizza
# 1  TWH4MjLtN1fKlF-7n6YXHg        lil-frankies-new-york       Lil Frankie's
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/ybrfmg...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/t0OsEV...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/front-street-pizza-br...           425
# 1  https://www.yelp.com/biz/lil-frankies-new-york...          1372
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
#
#                                         coordinates        transactions price  \
# 0    {'latitude': 40.70244, 'longitude': -73.98943}  [pickup, delivery]     $
# 1  {'latitude': 40.723625, 'longitude': -73.988555}  [pickup, delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '80 Front St', 'address2': '', 'a...  +17188753700
# 1  {'address1': '19 1st Ave', 'address2': '', 'ad...  +12124204900
#
#     display_phone     distance
# 0  (718) 875-3700   550.439226
# 1  (212) 420-4900  2079.035043

# %%
## concatenate the previous results and new results. 
businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                           alias  \
# 0  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 1  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 2  tpcCX_SHaNXqAzXOzbluJQ             fini-pizza-brooklyn
#
#                   name                                          image_url  \
# 0  Prince Street Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/HVjttL...
# 1            Juliana's  https://s3-media1.fl.yelpcdn.com/bphoto/OCDZ4n...
# 2           Fini Pizza  https://s3-media2.fl.yelpcdn.com/bphoto/ZJjnBs...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/prince-street-pizza-n...          4499
# 1      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2521
# 2      False  https://www.yelp.com/biz/fini-pizza-brooklyn?a...             9
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 2             [{'alias': 'pizza', 'title': 'Pizza'}]     3.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.72308755605564, 'longitude': -...  [pickup, delivery]
# 1  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 2     {'latitude': 40.71348, 'longitude': -73.96182}                  []
#
#   price                                           location         phone  \
# 0     $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 1    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 2   NaN  {'address1': '305 Bedford Ave', 'address2': ''...
#
#     display_phone     distance
# 0  (212) 966-4100  1961.877142
# 1  (718) 596-6700   308.569844
# 2                  2882.711683
#                         id                   alias  \
# 37  zaoZrYftFSEWnoXe3Xsolg        x-pizza-new-york
# 38  vmUNPvduTeWu24d--TbHAg            ops-brooklyn
# 39  S4uozcDEieoaXxIJ6TsUoQ  dellaroccos-brooklyn-3
#
#                              name  \
# 37                        X Pizza
# 38                            Ops
# 39  Dellarocco's Brick Oven Pizza
#
#                                             image_url  is_closed  \
# 37  https://s3-media2.fl.yelpcdn.com/bphoto/562tMr...      False
# 38  https://s3-media3.fl.yelpcdn.com/bphoto/_lBY7Q...      False
# 39  https://s3-media1.fl.yelpcdn.com/bphoto/RGsip2...      False
#
#                                                   url  review_count  \
# 37  https://www.yelp.com/biz/x-pizza-new-york?adju...             1
# 38  https://www.yelp.com/biz/ops-brooklyn?adjust_c...           173
# 39  https://www.yelp.com/biz/dellaroccos-brooklyn-...           327
#
#                                            categories  rating  \
# 37             [{'alias': 'pizza', 'title': 'Pizza'}]     3.0
# 38  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 39  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
#
#                                           coordinates        transactions  \
# 37  {'latitude': 40.70669773150677, 'longitude': -...  [pickup, delivery]
# 38      {'latitude': 40.70276, 'longitude': -73.9171}          [delivery]
# 39  {'latitude': 40.6950309, 'longitude': -73.9961...  [pickup, delivery]
#
#    price                                           location         phone  \
# 37   NaN  {'address1': '190 Front St', 'address2': '', '...
# 38    $$  {'address1': '346 Himrod St', 'address2': None...  +17183864009
# 39    $$  {'address1': '214 Hicks St', 'address2': None,...  +17188581010
#
#      display_phone     distance
# 37                   853.447905
# 38  (718) 386-4009  6508.236050
# 39  (718) 858-1010  1170.270033
